# %% [markdown]
# ## Importing the Necessary Packages

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures,MinMaxScaler,StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_squared_error
import plotly.graph_objs as go
from xgboost import XGBRegressor
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading Data

# %%
raw_data = pd.read_csv('1.05 STATION HIRONPOINT.csv')
raw_data.head()
# Out:
#    YEAR  MONTH  DAY  SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# 0  2017      1    1            101.52      14.48        25.83           0.00
# 1  2017      1    2            101.51      14.08        26.18           0.00
# 2  2017      1    3            101.44      15.01        26.30           0.08
# 3  2017      1    4            101.34      14.66        26.21           0.04
# 4  2017      1    5            101.32      13.23        25.94           0.02
#
#    MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  S_ICE EXTENT  \
# 0          3.45              68.81     15.99        12.643         5.516
# 1          4.23              68.69     15.46        12.644         5.387
# 2          4.81              73.44     15.34        12.713         5.232
# 3          4.66              72.94     15.57        12.954         5.149
# 4          4.98              69.50     14.65        12.956         5.065
#
#    HIGH   LOW
# 0  2.80  0.73
# 1  2.68  0.82
# 2  2.66  0.80
# 3  2.56  0.83
# 4  2.50  0.86

# %% [markdown]
# ## Handling Null Values

# %%
raw_data.isnull().sum()
# Out:
# YEAR                 0
# MONTH                0
# DAY                  0
# SURFACE PRESSURE     0
# DEW POINT            0
# TEMPERATURE          0
# PRECIPITATION        0
# MAX WIND SPD         0
# RELATIVE HUMIDITY    0
# MIN TEMP             0
# N_ICE EXTENT         0
# S_ICE EXTENT         0
# HIGH                 1
# LOW                  0
# dtype: int64

# %%
data_no_mv = raw_data.dropna(axis=0)
data_no_mv.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1460.000000  1460.000000  1460.000000       1460.000000  1460.000000
# mean   2018.500000     6.526027    15.728767        100.793432    21.368678
# std       1.118417     3.449033     8.806059          0.576262     5.736076
# min    2017.000000     1.000000     1.000000         98.970000     2.780000
# 25%    2017.750000     4.000000     8.000000        100.327500    16.997500
# 50%    2018.500000     7.000000    16.000000        100.830000    23.730000
# 75%    2019.250000    10.000000    23.000000        101.290000    26.210000
# max    2020.000000    12.000000    31.000000        101.920000    28.010000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1460.000000    1460.000000   1460.000000         1460.00000
# mean     29.565158       9.313692      5.216904           77.86539
# std       3.091541      18.968023      1.587857           11.48626
# min      15.530000       0.000000      1.930000           38.31000
# 25%      28.057500       0.000000      4.260000           69.94000
# 50%      29.950000       1.545000      4.900000           79.38000
# 75%      31.490000      11.242500      5.740000           87.76500
# max      36.080000     224.520000     22.300000           94.62000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT         HIGH          LOW
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean     23.058390     10.271556     11.062897     2.945329     0.845911
# std       5.084257      3.525952      5.797917     0.374364     0.421845
# min       9.740000      3.793000      2.080000     0.090000    -0.240000
# 25%      19.165000      6.828750      5.176250     2.720000     0.570000
# 50%      25.560000     11.151000     11.898500     2.970000     0.830000
# 75%      27.150000     13.462000     16.883000     3.220000     1.072500
# max      28.830000     15.071000     19.062000     3.790000     3.060000

# %% [markdown]
# ## Distribution Check and Dealing With Outliers

# %%
df = data_no_mv

# %%
sns.distplot(df['DEW POINT'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
q = df['PRECIPITATION'].quantile(0.99)
data_1 = df[df['PRECIPITATION']<q]
sns.distplot(data_1['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_cleaned = data_1.reset_index(drop=True)

# %%
data_cleaned = data_cleaned.drop(['HIGH'],axis=1)
data_cleaned.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1445.000000  1445.000000  1445.000000       1445.000000  1445.000000
# mean   2018.505882     6.507958    15.725952        100.799723    21.318443
# std       1.118096     3.457614     8.817772          0.575111     5.743869
# min    2017.000000     1.000000     1.000000         98.970000     2.780000
# 25%    2018.000000     4.000000     8.000000        100.330000    16.980000
# 50%    2019.000000     7.000000    16.000000        100.840000    23.630000
# 75%    2020.000000    10.000000    23.000000        101.290000    26.190000
# max    2020.000000    12.000000    31.000000        101.920000    28.010000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1445.000000    1445.000000   1445.000000        1445.000000
# mean     29.575716       8.022069      5.189889          77.713896
# std       3.104845      13.398900      1.558170          11.448102
# min      15.530000       0.000000      1.930000          38.310000
# 25%      28.060000       0.000000      4.250000          69.810000
# 50%      29.980000       1.420000      4.880000          79.190000
# 75%      31.510000      10.470000      5.720000          87.620000
# max      36.080000      84.240000     22.300000          94.620000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT          LOW
# count  1445.000000   1445.000000   1445.000000  1445.000000
# mean     23.021232     10.297266     11.012576     0.844298
# std       5.096190      3.530753      5.803321     0.422188
# min       9.740000      3.793000      2.080000    -0.240000
# 25%      19.100000      6.783000      5.114000     0.570000
# 50%      25.510000     11.207000     11.766000     0.830000
# 75%      27.150000     13.469000     16.879000     1.070000
# max      28.830000     15.071000     19.062000     3.060000

# %% [markdown]
# ## Setting Targets(Labels) and Inputs

# %%
targets = data_cleaned['LOW']
inputs = data_cleaned.drop(['LOW'],axis=1)

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# ### Scaling the data

# %%
scaler = StandardScaler()
scaler.fit(inputs)
inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model

# %%
poly = PolynomialFeatures(degree=2)
x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.fit_transform(x_test)

# %% [markdown]
# ### Training

# %%
reg_pol = LinearRegression()
reg_pol.fit(x_train_trans,y_train)
Train_score_PR = reg_pol.score(x_train_trans,y_train)
print("Training Score: ",Train_score_PR)
# Out:
# Training Score:  0.3484922402897983

# %% [markdown]
# ### Testing

# %%
y_pred_pol = reg_pol.predict(x_test_trans)

# %%
Test_score_PR = r2_score(y_test,y_pred_pol)
print("Testing Score: ",Test_score_PR)
# Out:
# Testing Score:  0.10224258782463169

# %%
mse = mean_squared_error(y_test, y_pred_pol)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.16622152027134307
# RMSE : 0.08311076013567154

# %% [markdown]
# ### Visulizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_pol, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_pol = reg_pol.predict(x_test_trans).flatten()
plt.scatter(y_test, y_pred_pol)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Support Vector Regression

# %% [markdown]
# ### Scaling the data

# %%
df_svr = data_cleaned
scaler=MinMaxScaler()
scaler.fit(inputs)
inputs_scaled_SVR = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled_SVR, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model and Training

# %%
svr = SVR(kernel='rbf',C=70,epsilon=0.1)
svr.fit(x_train,y_train)
Train_score_SVR = svr.score(x_train,y_train)
print("Training Score: ",Train_score_SVR)
# Out:
# Training Score:  0.616220568860788

# %% [markdown]
# ### Testing

# %%
y_pred_svr = svr.predict(x_test)

# %%
Test_score_SVR = r2_score(y_test,y_pred_svr)
print("Testing Score: ",Test_score_SVR)
# Out:
# Testing Score:  0.3033344949987411

# %%
mse = mean_squared_error(y_test, y_pred_svr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.12898896493799333
# RMSE : 0.06449448246899667

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_svr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_svr = svr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_svr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## XGB Regressor

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.15, random_state=22)

# %% [markdown]
# ### Model

# %%
xgbr = XGBRegressor(verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None,
#              enable_categorical=False, gamma=None, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %% [markdown]
# ### Training

# %%
xgbr.fit(x_train,y_train)
Train_score_XGB = xgbr.score(x_train,y_train)
print("Training Score: ",Train_score_XGB)
# Out:
# Training Score:  0.9967461110558018

# %% [markdown]
# ### Testing

# %%
y_pred_xgbr = xgbr.predict(x_test)
Test_score_XGB =  r2_score(y_test,y_pred_xgbr)
print("Testing Score: ",Test_score_XGB)
# Out:
# Testing Score:  0.43978334565029

# %%
mse = mean_squared_error(y_test, y_pred_xgbr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.11023927596492684
# RMSE : 0.05511963798246342

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_xgbr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_xgbr = xgbr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_xgbr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Random Forest Regression Model

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model

# %%
rfr = RandomForestRegressor(n_estimators=1000,random_state=0)

# %% [markdown]
# ### Training

# %%
rfr.fit(x_train,y_train)
Train_score_RFR = rfr.score(x_train,y_train)
print("Training Score: ",Train_score_RFR)
# Out:
# Training Score:  0.9278894713723747

# %% [markdown]
# ### Testing

# %%
y_pred_rfr = rfr.predict(x_test)
Test_score_RFR =  r2_score(y_test,y_pred_rfr)
print("Testing Score: ",Test_score_RFR)
# Out:
# Testing Score:  0.4540418800072694

# %%
mse = mean_squared_error(y_test, y_pred_rfr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.10108520127923921
# RMSE : 0.05054260063961961

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_rfr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_rfr = rfr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_rfr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()
