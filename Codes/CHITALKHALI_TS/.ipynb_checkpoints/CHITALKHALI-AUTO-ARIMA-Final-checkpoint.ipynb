# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARMA
from scipy.stats.distributions import chi2
from sklearn.metrics import r2_score,mean_squared_error
import warnings
from pmdarima.arima import auto_arima
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set()

# %%
raw_csv_data = pd.read_csv('1.01 CHARCHENGA_STATION.csv')
raw_csv_data.head()
df_comp =raw_csv_data.copy()

# %%
df_comp.Date = pd.to_datetime(df_comp.Date, dayfirst = True)
df_comp.set_index("Date",inplace=True)

# %%
df_comp = df_comp.asfreq('d') #'d' -> daily

# %%
df_comp2 = df_comp.copy()
del df_comp['LOW']

# %%
size = int(len(df_comp)*0.8)
df = df_comp.iloc[:size]
df_test = df_comp.iloc[size:]
df2 = df_comp2.iloc[:size]
df2_test = df_comp2.iloc[size:]

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.fit().llf
    L2 = mod_2.fit().llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %%
start_date = "2021-03-14"
end_date = "2021-12-31"

# %%
df_comp.head()
# Out:
#             SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# Date
# 2018-01-01            101.21      17.36        22.78          10.00
# 2018-01-02            101.24      17.65        21.83           0.00
# 2018-01-03            101.07      21.80        25.63           0.79
# 2018-01-04            101.01      22.08        27.90           0.99
# 2018-01-05            100.80      24.02        28.73          22.19
#
#             MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  \
# Date
# 2018-01-01          4.75              74.50     21.38        12.484
# 2018-01-02          4.40              81.56     19.55        13.764
# 2018-01-03          4.59              83.00     24.12        14.336
# 2018-01-04          4.16              75.06     25.76        14.196
# 2018-01-05          5.59              77.19     27.95        13.054
#
#             S_ICE EXTENT   HIGH
# Date
# 2018-01-01         6.384  1.548
# 2018-01-02         2.685  1.648
# 2018-01-03         2.351  1.558
# 2018-01-04         4.930  1.708
# 2018-01-05         7.392  1.848

# %%
mod_auto2 = auto_arima(df.HIGH,exogenous = df[['SURFACE PRESSURE','TEMPERATURE',
                                               'MAX WIND SPD','S_ICE EXTENT']]
                       ,m = 15, max_p = 6, max_q = 11)

# %%
mod_auto2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1168
# Model:             SARIMAX(6, 1, 9)x(2, 0, [], 15)   Log Likelihood                 157.016
# Date:                             Wed, 23 Mar 2022   AIC                           -270.032
# Time:                                     21:40:41   BIC                           -158.664
# Sample:                                 01-01-2018   HQIC                          -228.023
#                                       - 03-13-2021
# Covariance Type:                               opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# SURFACE PRESSURE    -0.3346      0.023    -14.347      0.000      -0.380      -0.289
# TEMPERATURE          0.0080      0.005      1.709      0.087      -0.001       0.017
# MAX WIND SPD         0.0203      0.003      7.653      0.000       0.015       0.026
# S_ICE EXTENT         0.0358      0.003     13.304      0.000       0.031       0.041
# ar.L1                0.0602      0.067      0.903      0.367      -0.070       0.191
# ar.L2                0.3743      0.067      5.556      0.000       0.242       0.506
# ar.L3                0.0436      0.072      0.605      0.545      -0.098       0.185
# ar.L4                0.2264      0.063      3.576      0.000       0.102       0.350
# ar.L5               -0.1903      0.062     -3.068      0.002      -0.312      -0.069
# ar.L6               -0.7377      0.064    -11.478      0.000      -0.864      -0.612
# ma.L1               -0.5941      0.072     -8.262      0.000      -0.735      -0.453
# ma.L2               -0.5003      0.101     -4.953      0.000      -0.698      -0.302
# ma.L3               -0.0354      0.096     -0.368      0.713      -0.224       0.153
# ma.L4               -0.0912      0.087     -1.047      0.295      -0.262       0.079
# ma.L5                0.2351      0.080      2.945      0.003       0.079       0.392
# ma.L6                0.6846      0.087      7.877      0.000       0.514       0.855
# ma.L7               -0.3213      0.041     -7.906      0.000      -0.401      -0.242
# ma.L8               -0.0620      0.042     -1.469      0.142      -0.145       0.021
# ma.L9               -0.2583      0.030     -8.647      0.000      -0.317      -0.200
# ar.S.L15            -0.1050      0.036     -2.882      0.004      -0.176      -0.034
# ar.S.L30             0.1692      0.027      6.376      0.000       0.117       0.221
# sigma2               0.0445      0.002     28.145      0.000       0.041       0.048
# ===================================================================================
# Ljung-Box (Q):                       74.19   Jarque-Bera (JB):               110.41
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.95   Skew:                             0.11
# Prob(H) (two-sided):                  0.58   Kurtosis:                         4.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df_auto_pred_pr2 = pd.DataFrame(mod_auto2.predict(n_periods = len(df_test[start_date:end_date]),exogenous = df_test[['SURFACE PRESSURE','TEMPERATURE',
                                               'MAX WIND SPD','S_ICE EXTENT']][start_date:end_date]),
                               index = df_test[start_date:end_date].index)

# %%
df_auto_pred_pr2[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.HIGH[start_date:end_date].plot(color = "blue")

# %%
acc =r2_score(df_test.HIGH[start_date:end_date],df_auto_pred_pr2[start_date:end_date])
print("Testing Score: ",acc)
# Out:
# Testing Score:  0.7285449343499903

# %%
mod_auto3 = auto_arima(df.HIGH,exogenous = df[['SURFACE PRESSURE','MAX WIND SPD','DEW POINT','S_ICE EXTENT']]
                       ,m = 15, max_p = 7, max_q = 11)

# %%
mod_auto3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                 1168
# Model:             SARIMAX(2, 1, 2)x(2, 0, [1], 15)   Log Likelihood                  63.596
# Date:                              Thu, 24 Mar 2022   AIC                           -101.191
# Time:                                      11:38:11   BIC                            -35.383
# Sample:                                  01-01-2018   HQIC                           -76.367
#                                        - 03-13-2021
# Covariance Type:                                opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept         5.234e-05      0.000      0.272      0.785      -0.000       0.000
# SURFACE PRESSURE    -0.2843      0.024    -11.719      0.000      -0.332      -0.237
# MAX WIND SPD         0.0195      0.003      7.274      0.000       0.014       0.025
# DEW POINT            0.0203      0.003      6.671      0.000       0.014       0.026
# S_ICE EXTENT         0.0275      0.003      9.802      0.000       0.022       0.033
# ar.L1               -0.2342      0.102     -2.305      0.021      -0.433      -0.035
# ar.L2                0.5113      0.044     11.491      0.000       0.424       0.599
# ma.L1               -0.1884      0.102     -1.851      0.064      -0.388       0.011
# ma.L2               -0.7606      0.096     -7.942      0.000      -0.948      -0.573
# ar.S.L15             0.5801      0.059      9.817      0.000       0.464       0.696
# ar.S.L30             0.2431      0.033      7.350      0.000       0.178       0.308
# ma.S.L15            -0.4493      0.057     -7.905      0.000      -0.561      -0.338
# sigma2               0.0516      0.002     27.584      0.000       0.048       0.055
# ===================================================================================
# Ljung-Box (Q):                      252.02   Jarque-Bera (JB):               196.63
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             0.08
# Prob(H) (two-sided):                  0.78   Kurtosis:                         5.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df_auto_pred_pr3 = pd.DataFrame(mod_auto3.predict(n_periods = len(df_test[start_date:end_date]),exogenous = df_test[['SURFACE PRESSURE','MAX WIND SPD','DEW POINT','S_ICE EXTENT']][start_date:end_date]),
                               index = df_test[start_date:end_date].index)

# %%
df_auto_pred_pr3[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.HIGH[start_date:end_date].plot(color = "blue")

# %%
acc =r2_score(df_test.HIGH[start_date:end_date],df_auto_pred_pr3[start_date:end_date])
print("Testing Score: ",acc)
# Out:
# Testing Score:  0.5415577253996278

# %%
mod_auto4 = auto_arima(df.HIGH,exogenous = df[['SURFACE PRESSURE','DEW POINT',
                                               'MAX WIND SPD','S_ICE EXTENT']]
                       ,m = 15, max_p = 6, max_q = 11)
