# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARMA
from scipy.stats.distributions import chi2
from sklearn.metrics import r2_score,mean_squared_error
import warnings
from pmdarima.arima import auto_arima
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set()

# %%
raw_csv_data = pd.read_csv('1.05 STATION HIRONPOINT.csv')
raw_csv_data.head()
df_comp =raw_csv_data.copy()

# %%
df_comp.Date = pd.to_datetime(df_comp.Date, dayfirst = True)
df_comp.set_index("Date",inplace=True)

# %%
df_comp = df_comp.asfreq('d') #'d' -> daily
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14080/3790306712.py in <module>
# ----> 1 df_comp = df_comp.asfreq('d') #'d' -> daily
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in asfreq(self, freq, method, how, normalize, fill_value)
#   10324         fill_value=None,
#   10325     ) -> DataFrame:
# > 10326         return super().asfreq(
#   10327             freq=freq,
#   10328             method=method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in asfreq(self, freq, method, how, normalize, fill_value)
#    7560         from pandas.core.resample import asfreq
#    7561
# -> 7562         return asfreq(
#    7563             self,
#    7564             freq,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\resample.py in asfreq(obj, freq, method, how, normalize, fill_value)
#    2049         dti = date_range(obj.index.min(), obj.index.max(), freq=freq)
#    2050         dti.name = obj.index.name
# -> 2051         new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#    2052         if normalize:
#    2053             new_obj.index = new_obj.index.normalize()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    4770         kwargs.pop("axis", None)
#    4771         kwargs.pop("labels", None)
# -> 4772         return super().reindex(**kwargs)
#    4773
#    4774     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4816
#    4817         # perform the reindex on the axes
# -> 4818         return self._reindex_axes(
#    4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4595         index = axes["index"]
#    4596         if index is not None:
# -> 4597             frame = frame._reindex_index(
#    4598                 index, method, copy, level, fill_value, limit, tolerance
#    4599             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4614             new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4615         )
# -> 4616         return self._reindex_with_indexers(
#    4617             {0: [new_index, indexer]},
#    4618             copy=copy,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881
#    4882             # TODO: speed up on homogeneous DataFrame objects
# -> 4883             new_data = new_data.reindex_indexer(
#    4884                 index,
#    4885                 indexer,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
df_comp2 = df_comp.copy()
del df_comp['LOW']

# %%
size = int(len(df_comp)*0.8)
df = df_comp.iloc[:size]
df_test = df_comp.iloc[size:]
df2 = df_comp2.iloc[:size]
df2_test = df_comp2.iloc[size:]

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.fit().llf
    L2 = mod_2.fit().llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %%
sgt.plot_acf(df.HIGH, lags = 40, zero = False)
plt.title("ACF HIGH", size=24)
plt.show()

# %%
sgt.plot_pacf(df.HIGH, lags=40, zero = False, method=('ols'))
plt.title("PACF HIGH", size=24)
plt.show()

# %%
start_date = "2021-03-14"
end_date = "2021-12-31"

# %%
df_comp.head()
# Out:
#             SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# Date
# 2019-01-01            101.75      14.46        23.44           0.00
# 2019-01-02            101.54      11.72        25.81           0.00
# 2019-01-03            101.34      17.09        24.42           3.24
# 2019-01-04            100.99      24.67        28.03          43.99
# 2019-01-05            100.64      25.64        31.09           7.09
#
#             MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  \
# Date
# 2019-01-01          4.62              73.38     15.35        12.934
# 2019-01-02          4.75              58.75     16.08        14.086
# 2019-01-03          7.23              75.94     19.63        14.546
# 2019-01-04          8.86              88.50     25.67        14.014
# 2019-01-05          9.38              80.06     28.09        12.862
#
#             S_ICE EXTENT    HIGH
# Date
# 2019-01-01         5.314  0.5910
# 2019-01-02         2.926  0.3440
# 2019-01-03         2.474  0.3038
# 2019-01-04         4.222  0.5338
# 2019-01-05         7.145  1.1570

# %%
mod_auto2 = auto_arima(df.HIGH,exogenous = df[['SURFACE PRESSURE','TEMPERATURE',
                                               'MAX WIND SPD','S_ICE EXTENT']]
                       ,m = 30, max_p = 12, max_q = 12)

# %%
mod_auto2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                  876
# Model:             SARIMAX(3, 1, 3)x(1, 0, [1, 2], 30)   Log Likelihood                  16.350
# Date:                                 Sat, 26 Mar 2022   AIC                             -4.699
# Time:                                         06:20:13   BIC                             62.140
# Sample:                                     01-01-2019   HQIC                            20.868
#                                           - 05-25-2021
# Covariance Type:                                   opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# SURFACE PRESSURE    -0.1419      0.039     -3.676      0.000      -0.218      -0.066
# TEMPERATURE          0.0101      0.004      2.337      0.019       0.002       0.019
# MAX WIND SPD         0.0277      0.004      7.284      0.000       0.020       0.035
# S_ICE EXTENT         0.0313      0.004      7.002      0.000       0.023       0.040
# ar.L1               -0.4992      0.152     -3.285      0.001      -0.797      -0.201
# ar.L2                0.0031      0.131      0.024      0.981      -0.254       0.260
# ar.L3                0.5512      0.094      5.856      0.000       0.367       0.736
# ma.L1                0.1388      0.158      0.879      0.379      -0.171       0.448
# ma.L2               -0.3716      0.143     -2.598      0.009      -0.652      -0.091
# ma.L3               -0.7288      0.166     -4.378      0.000      -1.055      -0.403
# ar.S.L30             0.7721      0.061     12.595      0.000       0.652       0.892
# ma.S.L30            -0.5819      0.068     -8.513      0.000      -0.716      -0.448
# ma.S.L60             0.0855      0.029      2.944      0.003       0.029       0.142
# sigma2               0.0560      0.002     34.960      0.000       0.053       0.059
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2072.46
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.65   Skew:                             0.94
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df_auto_pred_pr2 = pd.DataFrame(mod_auto2.predict(n_periods = len(df_test[start_date:end_date]),exogenous = df_test[['SURFACE PRESSURE','TEMPERATURE',
                                               'MAX WIND SPD','S_ICE EXTENT']][start_date:end_date]),
                               index = df_test[start_date:end_date].index)

# %%
df_auto_pred_pr2[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.HIGH[start_date:end_date].plot(color = "blue")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
acc =r2_score(df_test.HIGH[start_date:end_date],df_auto_pred_pr2[start_date:end_date])
print("Testing Score: ",acc)
# Out:
# Testing Score:  0.5996188523185519
