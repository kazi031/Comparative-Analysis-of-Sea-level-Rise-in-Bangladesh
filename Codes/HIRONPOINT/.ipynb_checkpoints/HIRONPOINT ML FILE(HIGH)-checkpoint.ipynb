# %% [markdown]
# ## Importing the Necessary Packages

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures,MinMaxScaler,StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_squared_error
import plotly.graph_objs as go
from xgboost import XGBRegressor
import seaborn as sns
from scipy.stats.distributions import chi2
import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt


sns.set()

# %% [markdown]
# ## Loading Data

# %%
raw_data = pd.read_csv('1.05 STATION HIRONPOINT.csv')
raw_data.head()
# Out:
#    YEAR  MONTH  DAY  SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# 0  2017      1    1            101.54      16.69        23.98           0.00
# 1  2017      1    2            101.53      16.66        24.37           0.01
# 2  2017      1    3            101.42      16.32        24.60           0.01
# 3  2017      1    4            101.34      17.26        24.09           0.01
# 4  2017      1    5            101.31      16.33        24.08           0.01
#
#    MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  S_ICE EXTENT  \
# 0          1.88              76.25     17.96        12.643         5.516
# 1          1.62              76.88     17.60        12.644         5.387
# 2          2.38              75.31     17.16        12.713         5.232
# 3          3.11              80.94     17.37        12.954         5.149
# 4          3.69              78.94     16.62        12.956         5.065
#
#     HIGH    LOW
# 0  0.906 -2.184
# 1  0.846 -2.124
# 2  0.766 -2.064
# 3  0.716 -1.984
# 4  0.666 -1.884

# %% [markdown]
# ## Handling Null Values

# %%
raw_data.isnull().sum()
# Out:
# YEAR                 0
# MONTH                0
# DAY                  0
# SURFACE PRESSURE     0
# DEW POINT            0
# TEMPERATURE          0
# PRECIPITATION        0
# MAX WIND SPD         0
# RELATIVE HUMIDITY    0
# MIN TEMP             0
# N_ICE EXTENT         0
# S_ICE EXTENT         0
# HIGH                 1
# LOW                  0
# dtype: int64

# %%
data_no_mv = raw_data.dropna(axis=0)
data_no_mv.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1460.000000  1460.000000  1460.000000       1460.000000  1460.000000
# mean   2018.501370     6.522603    15.738356        100.860027    22.241712
# std       1.119029     3.451044     8.799809          0.536813     4.690582
# min    2017.000000     1.000000     1.000000         99.210000     9.330000
# 25%    2017.750000     4.000000     8.000000        100.427500    18.345000
# 50%    2019.000000     7.000000    16.000000        100.910000    24.180000
# 75%    2020.000000    10.000000    23.000000        101.310000    26.230000
# max    2020.000000    12.000000    31.000000        101.920000    27.940000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1460.000000    1460.000000   1460.000000        1460.000000
# mean     27.980596      15.630034      3.201616          80.033596
# std       2.866740      31.301240      2.319251           8.116805
# min      19.450000       0.000000      0.040000          48.940000
# 25%      26.205000       0.000000      1.340000          74.310000
# 50%      29.145000       2.935000      2.770000          82.380000
# 75%      29.930000      18.090000      4.612500          86.560000
# max      33.500000     389.670000     11.000000          93.000000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT         HIGH          LOW
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean     24.223068     10.275003     11.054688     1.878397    -1.925562
# std       4.565971      3.527786      5.801186     0.941878     1.339417
# min      11.830000      3.793000      2.080000    -3.514000    -3.514000
# 25%      20.852500      6.828750      5.163250     1.226000    -2.884000
# 50%      26.440000     11.158000     11.883000     1.748000    -2.644000
# 75%      27.900000     13.462750     16.883000     2.386000    -1.684000
# max      29.410000     15.071000     19.062000     4.800000     1.180000

# %% [markdown]
# ## Distribution Check and Dealing With Outliers

# %%
df = data_no_mv

# %%
sns.distplot(df['DEW POINT'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
q = df['PRECIPITATION'].quantile(0.99)
data_1 = df[df['PRECIPITATION']<q]
sns.distplot(data_1['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_cleaned = data_1.reset_index(drop=True)

# %%
data_cleaned = data_cleaned.drop(['LOW'],axis=1)
data_cleaned.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1445.000000  1445.000000  1445.000000         1445.0000  1445.000000
# mean   2018.507958     6.514879    15.741869          100.8669    22.194374
# std       1.119321     3.466992     8.813264            0.5351     4.691525
# min    2017.000000     1.000000     1.000000           99.2100     9.330000
# 25%    2018.000000     4.000000     8.000000          100.4400    18.260000
# 50%    2019.000000     6.000000    16.000000          100.9100    24.060000
# 75%    2020.000000    10.000000    23.000000          101.3200    26.210000
# max    2020.000000    12.000000    31.000000          101.9200    27.940000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1445.000000    1445.000000   1445.000000        1445.000000
# mean     27.967336      13.601017      3.148360          79.927806
# std       2.878224      23.395246      2.267261           8.090508
# min      19.450000       0.000000      0.040000          48.940000
# 25%      26.170000       0.000000      1.320000          74.250000
# 50%      29.130000       2.720000      2.750000          82.250000
# 75%      29.930000      17.580000      4.530000          86.440000
# max      33.500000     150.200000     11.000000          93.000000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT         HIGH
# count  1445.000000   1445.000000   1445.000000  1445.000000
# mean     24.183813     10.301559     11.008118     1.875301
# std       4.573133      3.534261      5.811978     0.943054
# min      11.830000      3.793000      2.080000    -3.514000
# 25%      20.740000      6.780000      5.111000     1.226000
# 50%      26.370000     11.226000     11.755000     1.726000
# 75%      27.880000     13.477000     16.889000     2.386000
# max      29.410000     15.071000     19.062000     4.800000

# %% [markdown]
# ## Setting Targets(Labels) and Inputs

# %%
targets = data_cleaned['HIGH']
inputs = data_cleaned.drop(['HIGH'],axis=1)

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# ### Scaling the data

# %%
scaler = StandardScaler()
scaler.fit(inputs)
inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=42)

# %% [markdown]
# ### Model

# %%
poly = PolynomialFeatures(degree=2)
x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.fit_transform(x_test)

# %% [markdown]
# ### Training

# %%
reg_pol = LinearRegression()
reg_pol.fit(x_train_trans,y_train)
Train_score_PR = reg_pol.score(x_train_trans,y_train)
print("Training Score: ",Train_score_PR)
# Out:
# Training Score:  0.6341254619524896

# %% [markdown]
# ### Testing

# %%
y_pred_pol = reg_pol.predict(x_test_trans)

# %%
Test_score_PR = r2_score(y_test,y_pred_pol)
print("Testing Score: ",Test_score_PR)
# Out:
# Testing Score:  0.4777513629969472

# %%
mse = mean_squared_error(y_test, y_pred_pol)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.5127530143771221
# RMSE : 0.25637650718856103

# %% [markdown]
# ### Visulizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_pol, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_pol = reg_pol.predict(x_test_trans).flatten()
plt.scatter(y_test, y_pred_pol)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Support Vector Regression

# %% [markdown]
# ### Scaling the data

# %%
df_svr = data_cleaned
scaler=MinMaxScaler()
scaler.fit(inputs)
inputs_scaled_SVR = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled_SVR, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model and Training

# %%
svr = SVR(kernel='rbf',C=70,epsilon=0.1)
svr.fit(x_train,y_train)
Train_score_SVR = svr.score(x_train,y_train)
print("Training Score: ",Train_score_SVR)
# Out:
# Training Score:  0.8115737716259054

# %% [markdown]
# ### Testing

# %%
y_pred_svr = svr.predict(x_test)

# %%
Test_score_SVR = r2_score(y_test,y_pred_svr)
print("Testing Score: ",Test_score_SVR)
# Out:
# Testing Score:  0.7541039295576735

# %%
mse = mean_squared_error(y_test, y_pred_svr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.20399257648046634
# RMSE : 0.10199628824023317

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_svr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_svr = svr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_svr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## XGB Regressor

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.15, random_state=22)

# %% [markdown]
# ### Model

# %%
xgbr = XGBRegressor(verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None,
#              enable_categorical=False, gamma=None, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %% [markdown]
# ### Training

# %%
xgbr.fit(x_train,y_train)
Train_score_XGB = xgbr.score(x_train,y_train)
print("Training Score: ",Train_score_XGB)
# Out:
# Training Score:  0.9991651222948906

# %% [markdown]
# ### Testing

# %%
y_pred_xgbr = xgbr.predict(x_test)
Test_score_XGB =  r2_score(y_test,y_pred_xgbr)
print("Testing Score: ",Test_score_XGB)
# Out:
# Testing Score:  0.8283291993972102

# %%
mse = mean_squared_error(y_test, y_pred_xgbr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.14193992426134946
# RMSE : 0.07096996213067473

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_xgbr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_xgbr = xgbr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_xgbr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Random Forest Regression Model

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model

# %%
rfr = RandomForestRegressor(n_estimators=500,random_state=0)

# %% [markdown]
# ### Training

# %%
rfr.fit(x_train,y_train)
Train_score_RFR = rfr.score(x_train,y_train)
print("Training Score: ",Train_score_RFR)
# Out:
# Training Score:  0.9701578814426945

# %% [markdown]
# ### Testing

# %%
y_pred_rfr = rfr.predict(x_test)
Test_score_RFR =  r2_score(y_test,y_pred_rfr)
print("Testing Score: ",Test_score_RFR)
# Out:
# Testing Score:  0.8433872267212202

# %%
mse = mean_squared_error(y_test, y_pred_rfr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.12992417110782012
# RMSE : 0.06496208555391006

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_rfr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_rfr = rfr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_rfr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()
