# %% [markdown]
# ## Importing the Necessary Packages

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures,MinMaxScaler,StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_squared_error
import plotly.graph_objs as go
from xgboost import XGBRegressor
import seaborn as sns
from scipy.stats.distributions import chi2
import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt


sns.set()

# %% [markdown]
# ## Loading Data

# %%
raw_data = pd.read_csv('1.02 CHITALKHALI STATION.csv')
raw_data.head()
# Out:
#    YEAR  MONTH  DAY  SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# 0  2018      1    1            101.16      15.94        23.65           0.88
# 1  2018      1    2            101.01      16.66        21.85           1.90
# 2  2018      1    3            101.18      14.15        23.23           0.25
# 3  2018      1    4            101.37      11.59        20.83           0.35
# 4  2018      1    5            101.22      12.25        21.27           0.00
#
#    MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  S_ICE EXTENT  \
# 0          4.28              80.56     15.39        12.484         6.384
# 1          7.76              88.19     16.49        12.600         6.244
# 2          6.27              81.88     13.83        12.634         6.114
# 3          5.81              79.12     11.65        12.724         5.921
# 4          6.10              83.00     10.40        12.834         5.768
#
#       HIGH      LOW
# 0  1.60491 -1.18509
# 1  1.47491 -1.28509
# 2  1.56491 -1.36509
# 3  1.48491 -1.38509
# 4  1.39491 -1.48509

# %% [markdown]
# ## Handling Null Values

# %%
raw_data.isnull().sum()
# Out:
# YEAR                 0
# MONTH                0
# DAY                  0
# SURFACE PRESSURE     0
# DEW POINT            0
# TEMPERATURE          0
# PRECIPITATION        0
# MAX WIND SPD         0
# RELATIVE HUMIDITY    0
# MIN TEMP             0
# N_ICE EXTENT         0
# S_ICE EXTENT         0
# HIGH                 0
# LOW                  0
# dtype: int64

# %%
data_no_mv = raw_data.dropna(axis=0)
data_no_mv.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1461.000000  1461.000000  1461.000000       1461.000000  1461.000000
# mean   2019.500342     6.522930    15.729637        100.805934    21.647741
# std       1.118111     3.449884     8.803105          0.553406     5.192833
# min    2018.000000     1.000000     1.000000         99.110000     7.220000
# 25%    2019.000000     4.000000     8.000000        100.370000    17.560000
# 50%    2020.000000     7.000000    16.000000        100.860000    23.510000
# 75%    2020.000000    10.000000    23.000000        101.270000    26.190000
# max    2021.000000    12.000000    31.000000        101.900000    27.850000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1461.000000    1461.000000   1461.000000        1461.000000
# mean     29.102663      11.786988      6.234517          80.616051
# std       3.572199      21.751171      2.266376           9.888462
# min      18.960000       0.000000      1.580000          46.500000
# 25%      26.850000       0.000000      4.710000          73.880000
# 50%      29.950000       2.320000      5.980000          83.440000
# 75%      31.200000      15.110000      7.340000          88.560000
# max      38.740000     176.380000     22.950000          94.810000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT         HIGH          LOW
# count  1461.000000   1461.000000   1461.000000  1461.000000  1461.000000
# mean     22.478138     10.313081     11.245162     1.854136    -1.074376
# std       5.214499      3.545433      5.736673     0.738784     0.404510
# min       8.830000      3.793000      2.200000     0.214910    -2.079000
# 25%      18.470000      6.780000      5.555000     1.314910    -1.369000
# 50%      24.870000     11.207000     12.006000     1.762000    -1.085090
# 75%      26.730000     13.539000     16.989000     2.420000    -0.785090
# max      28.650000     15.071000     19.062000     3.977000     1.714910

# %% [markdown]
# ## Distribution Check and Dealing With Outliers

# %%
df = data_no_mv

# %%
sns.distplot(df['DEW POINT'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
q = df['PRECIPITATION'].quantile(0.99)
data_1 = df[df['PRECIPITATION']<q]
sns.distplot(data_1['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_cleaned = data_1.reset_index(drop=True)

# %%
data_cleaned = data_cleaned.drop(['LOW'],axis=1)
data_cleaned.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1446.000000  1446.000000  1446.000000       1446.000000  1446.000000
# mean   2019.504841     6.511065    15.737206        100.812994    21.596162
# std       1.119647     3.462635     8.812626          0.551256     5.194549
# min    2018.000000     1.000000     1.000000         99.110000     7.220000
# 25%    2019.000000     4.000000     8.000000        100.380000    17.512500
# 50%    2020.000000     6.500000    16.000000        100.860000    23.325000
# 75%    2021.000000    10.000000    23.000000        101.270000    26.177500
# max    2021.000000    12.000000    31.000000        101.900000    27.850000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1446.000000    1446.000000   1446.000000        1446.000000
# mean     29.103223      10.405422      6.196065          80.486501
# std       3.589857      16.945718      2.238856           9.856531
# min      18.960000       0.000000      1.580000          46.500000
# 25%      26.802500       0.000000      4.700000          73.750000
# 50%      29.970000       2.200000      5.960000          83.310000
# 75%      31.220000      14.262500      7.270000          88.500000
# max      38.740000     115.830000     22.950000          94.810000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT         HIGH
# count  1446.000000   1446.000000   1446.000000  1446.000000
# mean     22.432282     10.339373     11.197965     1.847567
# std       5.221500      3.549413      5.745249     0.737436
# min       8.830000      3.793000      2.200000     0.214910
# 25%      18.440000      6.836500      5.495500     1.311978
# 50%      24.810000     11.291000     11.870000     1.754955
# 75%      26.710000     13.546750     16.984000     2.406750
# max      28.650000     15.071000     19.062000     3.977000

# %% [markdown]
# ## Setting Targets(Labels) and Inputs

# %%
targets = data_cleaned['HIGH']
inputs = data_cleaned.drop(['HIGH'],axis=1)

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# ### Scaling the data

# %%
scaler = StandardScaler()
scaler.fit(inputs)
inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=42)

# %% [markdown]
# ### Model

# %%
poly = PolynomialFeatures(degree=2)
x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.fit_transform(x_test)

# %% [markdown]
# ### Training

# %%
reg_pol = LinearRegression()
reg_pol.fit(x_train_trans,y_train)
Train_score_PR = reg_pol.score(x_train_trans,y_train)
print("Training Score: ",Train_score_PR)
# Out:
# Training Score:  0.6385195871983602

# %% [markdown]
# ### Testing

# %%
y_pred_pol = reg_pol.predict(x_test_trans)

# %%
Test_score_PR = r2_score(y_test,y_pred_pol)
print("Testing Score: ",Test_score_PR)
# Out:
# Testing Score:  0.5604751735139417

# %%
mse = mean_squared_error(y_test, y_pred_pol)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.23405915539605668
# RMSE : 0.11702957769802834

# %% [markdown]
# ### Visulizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_pol, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_pol = reg_pol.predict(x_test_trans).flatten()
plt.scatter(y_test, y_pred_pol)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
#plt.xlim([0,plt.xlim()[1]])
#plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Support Vector Regression

# %% [markdown]
# ### Scaling the data

# %%
df_svr = data_cleaned
scaler=MinMaxScaler()
scaler.fit(inputs)
inputs_scaled_SVR = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled_SVR, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model and Training

# %%
svr = SVR(kernel='rbf',C=70,epsilon=0.1)
svr.fit(x_train,y_train)
Train_score_SVR = svr.score(x_train,y_train)
print("Training Score: ",Train_score_SVR)
# Out:
# Training Score:  0.8536476736445266

# %% [markdown]
# ### Testing

# %%
y_pred_svr = svr.predict(x_test)

# %%
Test_score_SVR = r2_score(y_test,y_pred_svr)
print("Testing Score: ",Test_score_SVR)
# Out:
# Testing Score:  0.6859787170338449

# %%
mse = mean_squared_error(y_test, y_pred_svr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.17001116194388433
# RMSE : 0.08500558097194216

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_svr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_svr = svr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_svr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## XGB Regressor

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.15, random_state=22)

# %% [markdown]
# ### Model

# %%
xgbr = XGBRegressor(verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None,
#              enable_categorical=False, gamma=None, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %% [markdown]
# ### Training

# %%
xgbr.fit(x_train,y_train)
Train_score_XGB = xgbr.score(x_train,y_train)
print("Training Score: ",Train_score_XGB)
# Out:
# Training Score:  0.9982472538775032

# %% [markdown]
# ### Testing

# %%
y_pred_xgbr = xgbr.predict(x_test)
Test_score_XGB =  r2_score(y_test,y_pred_xgbr)
print("Testing Score: ",Test_score_XGB)
# Out:
# Testing Score:  0.7935228603587658

# %%
mse = mean_squared_error(y_test, y_pred_xgbr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.11133557158926201
# RMSE : 0.055667785794631004

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_xgbr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_xgbr = xgbr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_xgbr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Random Forest Regression Model

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model

# %%
rfr = RandomForestRegressor(n_estimators=500,random_state=0)

# %% [markdown]
# ### Training

# %%
rfr.fit(x_train,y_train)
Train_score_RFR = rfr.score(x_train,y_train)
print("Training Score: ",Train_score_RFR)
# Out:
# Training Score:  0.9731747234306798

# %% [markdown]
# ### Testing

# %%
y_pred_rfr = rfr.predict(x_test)
Test_score_RFR =  r2_score(y_test,y_pred_rfr)
print("Testing Score: ",Test_score_RFR)
# Out:
# Testing Score:  0.8044904964468339

# %%
mse = mean_squared_error(y_test, y_pred_rfr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.10584886972049024
# RMSE : 0.05292443486024512

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_rfr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_rfr = rfr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_rfr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
plt.show()
