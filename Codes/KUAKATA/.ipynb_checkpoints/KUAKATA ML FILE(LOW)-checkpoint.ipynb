# %% [markdown]
# ## Importing the Necessary Packages

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures,MinMaxScaler,StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_squared_error
import plotly.graph_objs as go
from xgboost import XGBRegressor
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading Data

# %%
raw_data = pd.read_csv('1.03 STATION KUAKATA.csv')
raw_data.head()
# Out:
#    YEAR  MONTH  DAY  SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# 0  2018      1    1            101.17      16.10        23.80           2.13
# 1  2018      1    2            101.05      15.77        21.33           1.41
# 2  2018      1    3            101.20      13.13        23.65           0.01
# 3  2018      1    4            101.39      10.70        21.61           0.00
# 4  2018      1    5            101.26      10.73        21.41           0.00
#
#    MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  S_ICE EXTENT  \
# 0          4.23              79.25     16.54        12.484         6.384
# 1          6.40              84.00     16.45        12.600         6.244
# 2          5.70              74.69     14.35        12.634         6.114
# 3          5.47              71.00     12.60        12.724         5.921
# 4          5.91              74.38     10.99        12.834         5.768
#
#      HIGH     LOW
# 0 -0.9737 -2.8737
# 1 -0.8837 -2.8837
# 2 -0.7737 -2.9737
# 3 -0.5737 -2.9437
# 4 -0.6237 -2.9837

# %% [markdown]
# ## Handling Null Values

# %%
raw_data.isnull().sum()
# Out:
# YEAR                 0
# MONTH                0
# DAY                  0
# SURFACE PRESSURE     0
# DEW POINT            0
# TEMPERATURE          0
# PRECIPITATION        0
# MAX WIND SPD         0
# RELATIVE HUMIDITY    0
# MIN TEMP             0
# N_ICE EXTENT         0
# S_ICE EXTENT         0
# HIGH                 0
# LOW                  0
# dtype: int64

# %%
data_no_mv = raw_data.dropna(axis=0)
data_no_mv.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1461.000000  1461.000000  1461.000000       1461.000000  1461.000000
# mean   2019.500342     6.522930    15.729637        100.809699    21.564278
# std       1.118111     3.449884     8.803105          0.562178     5.412357
# min    2018.000000     1.000000     1.000000         99.150000     5.060000
# 25%    2019.000000     4.000000     8.000000        100.370000    17.670000
# 50%    2020.000000     7.000000    16.000000        100.870000    23.580000
# 75%    2020.000000    10.000000    23.000000        101.280000    26.170000
# max    2021.000000    12.000000    31.000000        101.920000    27.830000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1461.000000    1461.000000   1461.000000        1461.000000
# mean     29.300794      12.626441      5.721786          78.827981
# std       3.228865      25.573935      1.965146          10.603391
# min      16.630000       0.000000      1.950000          42.120000
# 25%      27.570000       0.000000      4.490000          71.250000
# 50%      29.910000       2.410000      5.380000          81.750000
# 75%      31.150000      14.820000      6.460000          87.560000
# max      38.510000     303.640000     22.520000          94.190000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT         HIGH          LOW
# count  1461.000000   1461.000000   1461.000000  1461.000000  1461.000000
# mean     23.092820     10.313081     11.253992     0.750622    -1.304429
# std       5.085687      3.545433      5.728337     0.894928     0.741948
# min       9.620000      3.793000      2.200000    -1.573700    -3.163700
# 25%      19.230000      6.780000      5.584000     0.226300    -1.623700
# 50%      25.540000     11.207000     12.006000     0.966300    -1.230000
# 75%      27.190000     13.539000     16.989000     1.380000    -0.780000
# max      28.870000     15.071000     19.062000     3.930000     0.326300

# %% [markdown]
# ## Distribution Check and Dealing With Outliers

# %%
df = data_no_mv

# %%
sns.distplot(df['DEW POINT'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
q = df['PRECIPITATION'].quantile(0.99)
data_1 = df[df['PRECIPITATION']<q]
sns.distplot(data_1['PRECIPITATION'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_cleaned = data_1.reset_index(drop=True)

# %%
data_cleaned = data_cleaned.drop(['HIGH'],axis=1)
data_cleaned.describe(include='all')
# Out:
#               YEAR        MONTH          DAY  SURFACE PRESSURE    DEW POINT  \
# count  1446.000000  1446.000000  1446.000000       1446.000000  1446.000000
# mean   2019.505533     6.511065    15.737898        100.817365    21.512856
# std       1.119644     3.461436     8.814806          0.558582     5.416064
# min    2018.000000     1.000000     1.000000         99.150000     5.060000
# 25%    2019.000000     4.000000     8.000000        100.380000    17.520000
# 50%    2020.000000     7.000000    16.000000        100.870000    23.400000
# 75%    2021.000000    10.000000    23.000000        101.280000    26.147500
# max    2021.000000    12.000000    31.000000        101.920000    27.830000
#
#        TEMPERATURE  PRECIPITATION  MAX WIND SPD  RELATIVE HUMIDITY  \
# count  1446.000000    1446.000000   1446.000000        1446.000000
# mean     29.306328      10.886155      5.687531          78.688091
# std       3.243996      18.544403      1.936468          10.567866
# min      16.630000       0.000000      1.950000          42.120000
# 25%      27.562500       0.000000      4.482500          71.190000
# 50%      29.945000       2.280000      5.360000          81.620000
# 75%      31.180000      14.162500      6.410000          87.500000
# max      38.510000     123.220000     22.520000          94.190000
#
#           MIN TEMP  N_ICE EXTENT  S_ICE EXTENT          LOW
# count  1446.000000   1446.000000   1446.000000  1446.000000
# mean     23.051362     10.335770     11.211770    -1.302833
# std       5.094700      3.550044      5.738765     0.742515
# min       9.620000      3.793000      2.200000    -3.163700
# 25%      19.187500      6.793500      5.539000    -1.611200
# 50%      25.495000     11.291000     11.877500    -1.223700
# 75%      27.180000     13.546750     16.988500    -0.772500
# max      28.870000     15.071000     19.062000     0.326300

# %% [markdown]
# ## Setting Targets(Labels) and Inputs

# %%
targets = data_cleaned['LOW']
inputs = data_cleaned.drop(['LOW'],axis=1)

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# ### Scaling the data

# %%
scaler = StandardScaler()
scaler.fit(inputs)
inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model

# %%
poly = PolynomialFeatures(degree=2)
x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.fit_transform(x_test)

# %% [markdown]
# ### Training

# %%
reg_pol = LinearRegression()
reg_pol.fit(x_train_trans,y_train)
Train_score_PR = reg_pol.score(x_train_trans,y_train)
print("Training Score: ",Train_score_PR)
# Out:
# Training Score:  0.8392312178828846

# %% [markdown]
# ### Testing

# %%
y_pred_pol = reg_pol.predict(x_test_trans)

# %%
Test_score_PR = r2_score(y_test,y_pred_pol)
print("Testing Score: ",Test_score_PR)
# Out:
# Testing Score:  0.8058320548138436

# %%
mse = mean_squared_error(y_test, y_pred_pol)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.11174872843740767
# RMSE : 0.055874364218703836

# %% [markdown]
# ### Visulizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_pol, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_pol = reg_pol.predict(x_test_trans).flatten()
plt.scatter(y_test, y_pred_pol)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Support Vector Regression

# %% [markdown]
# ### Scaling the data

# %%
df_svr = data_cleaned
scaler=MinMaxScaler()
scaler.fit(inputs)
inputs_scaled_SVR = scaler.transform(inputs)

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled_SVR, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model and Training

# %%
svr = SVR(kernel='rbf',C=70,epsilon=0.1)
svr.fit(x_train,y_train)
Train_score_SVR = svr.score(x_train,y_train)
print("Training Score: ",Train_score_SVR)
# Out:
# Training Score:  0.9571582594720441

# %% [markdown]
# ### Testing

# %%
y_pred_svr = svr.predict(x_test)

# %%
Test_score_SVR = r2_score(y_test,y_pred_svr)
print("Testing Score: ",Test_score_SVR)
# Out:
# Testing Score:  0.9004315004229919

# %%
mse = mean_squared_error(y_test, y_pred_svr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.05730427444902735
# RMSE : 0.028652137224513676

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_svr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_svr = svr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_svr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## XGB Regressor

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.15, random_state=22)

# %% [markdown]
# ### Model

# %%
xgbr = XGBRegressor(verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None,
#              enable_categorical=False, gamma=None, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %% [markdown]
# ### Training

# %%
xgbr.fit(x_train,y_train)
Train_score_XGB = xgbr.score(x_train,y_train)
print("Training Score: ",Train_score_XGB)
# Out:
# Training Score:  0.9995369405188784

# %% [markdown]
# ### Testing

# %%
y_pred_xgbr = xgbr.predict(x_test)
Test_score_XGB =  r2_score(y_test,y_pred_xgbr)
print("Testing Score: ",Test_score_XGB)
# Out:
# Training Score:  0.950164966409622

# %%
mse = mean_squared_error(y_test, y_pred_xgbr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.026856409201606656
# RMSE : 0.013428204600803328

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_xgbr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_xgbr = xgbr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_xgbr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()

# %% [markdown]
# ## Random Forest Regression Model

# %% [markdown]
# ### Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.2, random_state=22)

# %% [markdown]
# ### Model

# %%
rfr = RandomForestRegressor(n_estimators=1000,random_state=0)

# %% [markdown]
# ### Training

# %%
rfr.fit(x_train,y_train)
Train_score_RFR = rfr.score(x_train,y_train)
print("Training Score: ",Train_score_RFR)
# Out:
# Training Score:  0.9927112705047658

# %% [markdown]
# ### Testing

# %%
y_pred_rfr = rfr.predict(x_test)
Test_score_RFR =  r2_score(y_test,y_pred_rfr)
print("Testing Score: ",Test_score_RFR)
# Out:
# Testing Score:  0.9247050609177857

# %%
mse = mean_squared_error(y_test, y_pred_rfr)
print("MSE :",mse)
print("RMSE :",mse*(1/2.0))
# Out:
# MSE : 0.04333420581931057
# RMSE : 0.021667102909655286

# %% [markdown]
# ### Visualizing Predictions

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(30,10))
plt.plot(x_ax, y_test,label="original")
plt.plot(x_ax, y_pred_rfr, label="Predicted")
plt.legend()
plt.show()

# %%
y_pred_rfr = rfr.predict(x_test).flatten()
plt.scatter(y_test, y_pred_rfr)
plt.xlabel('True Values [M]')
plt.ylabel('Predictions [M]')
plt.axis('equal')
plt.axis('square')

_ = plt.plot([-100, 100], [-100, 100])
plt.show()
