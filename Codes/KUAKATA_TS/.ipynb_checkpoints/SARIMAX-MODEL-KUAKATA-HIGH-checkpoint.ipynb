# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from scipy.stats.distributions import chi2
from sklearn.metrics import r2_score,mean_squared_error
import warnings
from pmdarima.arima import auto_arima
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set()

# %%
raw_csv_data = pd.read_csv('KUAKATA.csv')
raw_csv_data.head()
df_comp =raw_csv_data.copy()

# %%
df_comp.Date = pd.to_datetime(df_comp.Date, dayfirst = True)
df_comp.set_index("Date",inplace=True)

# %%
df_comp = df_comp.asfreq('d') #'d' -> daily

# %%
df_comp2 = df_comp.copy()
del df_comp['LOW']

# %%
size = int(len(df_comp)*0.8)
df = df_comp.iloc[:size]
df_test = df_comp.iloc[size:]
df2 = df_comp2.iloc[:size]
df2_test = df_comp2.iloc[size:]

# %%
df_test.tail()
# Out:
#             SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# Date
# 2021-12-27            101.73      16.05        22.53           0.00
# 2021-12-28            101.68      16.44        22.84           0.00
# 2021-12-29            101.68      15.12        23.22           0.06
# 2021-12-30            101.81      16.44        23.92           0.02
# 2021-12-31            101.88      16.18        23.07           0.09
#
#             MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  \
# Date
# 2021-12-27          4.77              81.44     16.30        12.947
# 2021-12-28          5.68              82.31     17.05        12.978
# 2021-12-29          4.54              75.31     16.53        13.050
# 2021-12-30          7.35              80.50     16.67        13.149
# 2021-12-31          7.59              82.50     16.65        13.183
#
#             S_ICE EXTENT   HIGH
# Date
# 2021-12-27         6.185  0.602
# 2021-12-28         5.846  0.557
# 2021-12-29         5.679  0.670
# 2021-12-30         5.679  0.782
# 2021-12-31         5.679  0.898

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.fit().llf
    L2 = mod_2.fit().llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %%
start_date = "2021-05-26"
end_date = "2021-12-31"

# %%
df_comp.head()
# Out:
#             SURFACE PRESSURE  DEW POINT  TEMPERATURE  PRECIPITATION  \
# Date
# 2019-01-01            101.75      14.46        23.44           0.00
# 2019-01-02            101.54      11.72        25.81           0.00
# 2019-01-03            101.34      17.09        24.42           3.24
# 2019-01-04            100.99      24.67        28.03          43.99
# 2019-01-05            100.64      25.64        31.09           7.09
#
#             MAX WIND SPD  RELATIVE HUMIDITY  MIN TEMP  N_ICE EXTENT  \
# Date
# 2019-01-01          4.62              73.38     15.35        12.934
# 2019-01-02          4.75              58.75     16.08        14.086
# 2019-01-03          7.23              75.94     19.63        14.546
# 2019-01-04          8.86              88.50     25.67        14.014
# 2019-01-05          9.38              80.06     28.09        12.862
#
#             S_ICE EXTENT    HIGH
# Date
# 2019-01-01         5.314  0.5910
# 2019-01-02         2.926  0.3440
# 2019-01-03         2.474  0.3038
# 2019-01-04         4.222  0.5338
# 2019-01-05         7.145  1.1570

# %%
model_sarimax1 = SARIMAX(df.HIGH, exog = df[['SURFACE PRESSURE','TEMPERATURE','MAX WIND SPD','S_ICE EXTENT']], order=(2,1,1), seasonal_order = (2,0,1,15))
results_sarimax1 = model_sarimax1.fit()
results_sarimax1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                   HIGH   No. Observations:                  876
# Model:             SARIMAX(26, 1, 16)x(1, 0, [1], 30)   Log Likelihood                 126.901
# Date:                                Sat, 26 Mar 2022   AIC                           -155.801
# Time:                                        13:38:46   BIC                             78.136
# Sample:                                    01-01-2019   HQIC                           -66.315
#                                          - 05-25-2021
# Covariance Type:                                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# SURFACE PRESSURE    -0.1484      0.036     -4.165      0.000      -0.218      -0.079
# TEMPERATURE          0.0116      0.004      2.820      0.005       0.004       0.020
# MAX WIND SPD         0.0241      0.004      6.795      0.000       0.017       0.031
# S_ICE EXTENT         0.0289      0.004      7.155      0.000       0.021       0.037
# ar.L1               -0.0691      0.449     -0.154      0.878      -0.950       0.812
# ar.L2               -0.1999      0.438     -0.456      0.648      -1.058       0.659
# ar.L3               -0.3181      0.297     -1.071      0.284      -0.900       0.264
# ar.L4               -0.1670      0.267     -0.625      0.532      -0.691       0.357
# ar.L5               -0.4916      0.205     -2.400      0.016      -0.893      -0.090
# ar.L6                0.0267      0.269      0.099      0.921      -0.500       0.553
# ar.L7               -0.6355      0.275     -2.313      0.021      -1.174      -0.097
# ar.L8               -0.0144      0.309     -0.046      0.963      -0.620       0.592
# ar.L9                0.0495      0.209      0.237      0.813      -0.360       0.459
# ar.L10              -0.4691      0.227     -2.069      0.039      -0.914      -0.025
# ar.L11              -0.0174      0.264     -0.066      0.947      -0.534       0.499
# ar.L12              -0.0896      0.267     -0.335      0.737      -0.613       0.434
# ar.L13               0.0293      0.245      0.120      0.905      -0.450       0.509
# ar.L14              -0.1173      0.215     -0.545      0.586      -0.539       0.305
# ar.L15               0.1785      0.207      0.863      0.388      -0.227       0.584
# ar.L16               0.3752      0.218      1.721      0.085      -0.052       0.802
# ar.L17               0.0146      0.101      0.144      0.885      -0.184       0.213
# ar.L18               0.1250      0.091      1.366      0.172      -0.054       0.304
# ar.L19               0.1173      0.078      1.507      0.132      -0.035       0.270
# ar.L20               0.0464      0.091      0.508      0.612      -0.133       0.226
# ar.L21               0.0126      0.098      0.128      0.898      -0.180       0.205
# ar.L22               0.1080      0.083      1.305      0.192      -0.054       0.270
# ar.L23               0.1005      0.093      1.086      0.277      -0.081       0.282
# ar.L24              -0.1372      0.074     -1.852      0.064      -0.282       0.008
# ar.L25               0.0459      0.108      0.427      0.669      -0.165       0.257
# ar.L26              -0.0845      0.095     -0.885      0.376      -0.272       0.103
# ma.L1               -0.3271      0.449     -0.728      0.466      -1.207       0.553
# ma.L2               -0.0449      0.478     -0.094      0.925      -0.982       0.893
# ma.L3                0.1094      0.344      0.318      0.751      -0.566       0.785
# ma.L4               -0.1241      0.355     -0.350      0.727      -0.820       0.572
# ma.L5                0.3277      0.262      1.249      0.212      -0.187       0.842
# ma.L6               -0.3758      0.289     -1.299      0.194      -0.943       0.191
# ma.L7                0.4071      0.291      1.401      0.161      -0.162       0.977
# ma.L8               -0.2302      0.289     -0.797      0.425      -0.796       0.336
# ma.L9               -0.2645      0.255     -1.039      0.299      -0.763       0.235
# ma.L10               0.3559      0.257      1.383      0.167      -0.148       0.860
# ma.L11              -0.2191      0.289     -0.759      0.448      -0.785       0.347
# ma.L12              -0.0197      0.264     -0.075      0.941      -0.538       0.499
# ma.L13              -0.0693      0.227     -0.305      0.760      -0.515       0.376
# ma.L14               0.0197      0.233      0.084      0.933      -0.437       0.477
# ma.L15              -0.1510      0.218     -0.693      0.488      -0.578       0.276
# ma.L16              -0.3377      0.230     -1.466      0.143      -0.789       0.114
# ar.S.L30             0.4389      0.278      1.580      0.114      -0.106       0.983
# ma.S.L30            -0.3232      0.305     -1.060      0.289      -0.921       0.275
# sigma2               0.0434      0.001     29.321      0.000       0.041       0.046
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):              2167.96
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.69   Skew:                             1.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df_pred_sarimax1 = results_sarimax1.predict(start = start_date, end = end_date,
                                           exog = df_test[['SURFACE PRESSURE','TEMPERATURE','MAX WIND SPD','S_ICE EXTENT']][start_date:end_date])

# %%
df_pred_sarimax1[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.HIGH[start_date:end_date].plot(color = "blue")
plt.legend(['Predicted', 'Real Values'])

# %%
acc =r2_score(df_test.HIGH[start_date:end_date],df_pred_sarimax1[start_date:end_date])
print("Testing Score: ",acc)
# Out:
# Testing Score:  0.6968635634738017

# %%
df['res'] = results_sarimax1.resid.iloc[:]
sgt.plot_acf(df.res[1:], zero = False, lags = 40)
plt.title("ACF Of Residuals for ",size=20)
plt.show()

# %%
df['res'] = results_sarimax1.resid.iloc[:]
sgt.plot_pacf(df.res[1:], zero = False, lags = 40)
plt.title("PACF Of Residuals for ",size=20)
plt.show()
